# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
import pandas as pd

ratings = pd.read_csv(r"C:/Users/USER/Downloads/archive TY/title.ratings.tsv", sep="\t")
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2173
# 1  tt0000002            5.5       298
# 2  tt0000003            6.4      2238
# 3  tt0000004            5.2       192
# 4  tt0000005            6.2      2980

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1606991 entries, 0 to 1606990
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1606991 non-null  object
#  1   averageRating  1606991 non-null  float64
#  2   numVotes       1606991 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 36.8+ MB

# %%
ratings.describe()
# Out:
#        averageRating      numVotes
# count   1.606991e+06  1.606991e+06
# mean    6.944752e+00  1.020893e+03
# std     1.390596e+00  1.788420e+04
# min     1.000000e+00  5.000000e+00
# 25%     6.200000e+00  1.200000e+01
# 50%     7.100000e+00  2.600000e+01
# 75%     7.900000e+00  1.000000e+02
# max     1.000000e+01  3.089933e+06

# %%
# Create histogram
plt.figure(figsize=(10, 6))
ratings['averageRating'].hist(bins=20, color='skyblue')
plt.title('Distribution of Movie Ratings')
plt.xlabel('Rating')
plt.ylabel('Number of Movies')
plt.show()

# %%
# Create rating categories
bins = [0, 2, 4, 6, 8, 10]
labels = ['Very Bad (0-2)', 'Bad (2-4)', 'Average (4-6)', 'Good (6-8)', 'Excellent (8-10)']
ratings['rating_category'] = pd.cut(ratings['averageRating'], bins=bins, labels=labels)

# Count movies in each category
category_counts = ratings['rating_category'].value_counts()

# %%
# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Movies by Rating Category')
plt.show()

# %%
# Get top 10 most voted movies
top10_popular = ratings.nlargest(10, 'numVotes')[['tconst', 'averageRating', 'numVotes']]
top10_popular
# Out:
#            tconst  averageRating  numVotes
# 84699   tt0111161            9.3   3089933
# 260886  tt0468569            9.1   3065283
# 691959  tt1375666            8.8   2722829
# 101654  tt0137523            8.8   2506771
# 455895  tt0944947            9.2   2472858
# 83589   tt0109830            8.8   2413094
# 415117  tt0816692            8.7   2395797
# 444462  tt0903747            9.5   2386060
# 84479   tt0110912            8.8   2363992
# 99377   tt0133093            8.7   2181968

# %%
# Filter for movies with decent number of votes
popular_movies = ratings[ratings['numVotes'] >= 1000]

# Get top 10 highest rated from popular movies
top10_rated = popular_movies.nlargest(10, 'averageRating')[['tconst', 'averageRating', 'numVotes']]
top10_rated
# Out:
#             tconst  averageRating  numVotes
# 988499   tt2301451           10.0    258761
# 370794   tt0701989            9.9     14593
# 536255  tt11028174            9.9     27070
# 553428  tt11294360            9.9     26235
# 596598   tt1204265            9.9     20913
# 604650  tt12187040            9.9     67909
# 634531  tt12746312            9.9      1132
# 830982   tt1683088            9.9     89708
# 937518  tt21151974            9.9     40951
# 956611   tt2178784            9.9    133646

# %%
import os

folder_path = r"C:/Users/USER/Downloads"
files = os.listdir(folder_path)

print("Files inside Downloads:\n")
for f in files:
    print(f)
# Out:
# Files inside Downloads:
#
# Anaconda3-2024.06-1-Windows-x86_64.exe
# Anaconda3-2025.06-0-Windows-x86_64.exe
# archive TY
# archive.zip
# bag.png
# bg.jpg
# BlueStacksInstaller_5.22.86.1001_native.exe
# build.sh
# ChromeSetup.exe
# Consolidated_Account_Statement_Zenith Bank (1).xls
# Consolidated_Account_Statement_Zenith Bank.xls
# converted_02f054b0-25c6-4879-ab25-8e528fc76a26.pdf
# converted_81e07ac9-283c-4ba8-907a-454dccdc6732.pdf
# converted_ACTA-2023-1-18 (1).docx
# converted_ACTA-2023-1-18 (10).docx
# converted_ACTA-2023-1-18 (11).docx
# converted_ACTA-2023-1-18 (12).docx
# converted_ACTA-2023-1-18 (13).docx
# converted_ACTA-2023-1-18 (14).docx
# converted_ACTA-2023-1-18 (15).docx
# converted_ACTA-2023-1-18 (2).docx
# converted_ACTA-2023-1-18 (3).docx
# converted_ACTA-2023-1-18 (4).docx
# converted_ACTA-2023-1-18 (5).docx
# converted_ACTA-2023-1-18 (6).docx
# converted_ACTA-2023-1-18 (7).docx
# converted_ACTA-2023-1-18 (8).docx
# converted_ACTA-2023-1-18 (9).docx
# ...

# %%
full_data = ratings.merge(basics, on='tconst')
full_data.head()
# Out:
#       tconst  averageRating  numVotes rating_category titleType  \
# 0  tt0000001            5.7      2173   Average (4-6)     short
# 1  tt0000002            5.5       298   Average (4-6)     short
# 2  tt0000003            6.4      2238      Good (6-8)     short
# 3  tt0000004            5.2       192   Average (4-6)     short
# 4  tt0000005            6.2      2980      Good (6-8)     short
#
#              primaryTitle           originalTitle  isAdult startYear endYear  \
# 0              Carmencita              Carmencita        0      1894      \N
# 1  Le clown et ses chiens  Le clown et ses chiens        0      1892      \N
# 2            Poor Pierrot          Pauvre Pierrot        0      1892      \N
# 3             Un bon bock             Un bon bock        0      1892      \N
# 4        Blacksmith Scene        Blacksmith Scene        0      1893      \N
#
#   runtimeMinutes                    genres
# 0              1         Documentary,Short
# ...

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1606991 entries, 0 to 1606990
# Data columns (total 12 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   tconst           1606991 non-null  object
#  1   averageRating    1606991 non-null  float64
#  2   numVotes         1606991 non-null  int64
#  3   rating_category  1606991 non-null  category
#  4   titleType        1606991 non-null  object
#  5   primaryTitle     1606990 non-null  object
#  6   originalTitle    1606990 non-null  object
#  7   isAdult          1606991 non-null  int64
#  8   startYear        1606991 non-null  object
#  9   endYear          1606991 non-null  object
#  10  runtimeMinutes   1606991 non-null  object
#  11  genres           1606987 non-null  object
# dtypes: category(1), float64(1), int64(2), object(8)
# memory usage: 136.4+ MB

# %%
import os
folder_path = r"C:/Users/USER/Downloads/archive TY/"
files = os.listdir(folder_path)
print("Files in folder:")
for f in files:
    print(f)
# Out:
# Files in folder:
# name.basics.tsv
# title.akas.tsv
# title.basics.tsv
# title.principals.tsv
# title.ratings.tsv
